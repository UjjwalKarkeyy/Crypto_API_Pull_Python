# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

# %%
df = pd.DataFrame()

def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '7f222d29-d6b7-4a3e-882d-e93a59bd7d83',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    # Use this if have to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = pd.concat([df, df2], ignore_index = True)

    # To create a csv and append data to it
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df

    #if not os.path.isfile(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv'):
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', header='column_names')
    #else:
        #df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', mode='a', header=False)
        
    #Then to read in the file: df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
# df72 = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')
# df72

# %%
df
# Out:
#        id         name symbol         slug  num_market_pairs  \
# 0       1      Bitcoin    BTC      bitcoin             12198
# 1    1027     Ethereum    ETH     ethereum             10316
# 2     825  Tether USDt   USDT       tether            129964
# 3      52          XRP    XRP          xrp              1617
# 4    1839          BNB    BNB          bnb              2553
# 5    5426       Solana    SOL       solana               927
# 6    3408         USDC   USDC     usd-coin             28281
# 7      74     Dogecoin   DOGE     dogecoin              1229
# 8    2010      Cardano    ADA      cardano              1524
# 9    1958         TRON    TRX         tron              1181
# 10  20947          Sui    SUI          sui               667
# 11  32196  Hyperliquid   HYPE  hyperliquid                87
# 12   1975    Chainlink   LINK    chainlink              2016
# 13   5805    Avalanche   AVAX    avalanche               917
# 14    512      Stellar    XLM      stellar               709
# 15      1      Bitcoin    BTC      bitcoin             12198
# 16   1027     Ethereum    ETH     ethereum             10316
# 17    825  Tether USDt   USDT       tether            129964
# 18     52          XRP    XRP          xrp              1617
# 19   1839          BNB    BNB          bnb              2553
# 20   5426       Solana    SOL       solana               927
# 21   3408         USDC   USDC     usd-coin             28281
# 22     74     Dogecoin   DOGE     dogecoin              1229
# 23   2010      Cardano    ADA      cardano              1524
# 24   1958         TRON    TRX         tron              1181
# 25  20947          Sui    SUI          sui               667
# 26  32196  Hyperliquid   HYPE  hyperliquid                87
# 27   1975    Chainlink   LINK    chainlink              2016
# 28   5805    Avalanche   AVAX    avalanche               917
# 29    512      Stellar    XLM      stellar               709
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-10-01T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2022-07-12T08:03:11.000Z
# 11  2024-07-15T10:14:50.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2020-07-13T00:00:00.000Z
# 14  2014-08-05T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2013-08-04T00:00:00.000Z
# 19  2017-07-25T00:00:00.000Z
# 20  2020-04-10T00:00:00.000Z
# 21  2018-10-08T00:00:00.000Z
# 22  2013-12-15T00:00:00.000Z
# 23  2017-10-01T00:00:00.000Z
# 24  2017-09-13T00:00:00.000Z
# 25  2022-07-12T08:03:11.000Z
# 26  2024-07-15T10:14:50.000Z
# 27  2017-09-20T00:00:00.000Z
# 28  2020-07-13T00:00:00.000Z
# 29  2014-08-05T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 9   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 10  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 11  [decentralized-exchange-dex-token, defi, deriv...  1.000000e+09
# 12  [platform, defi, oracles, smart-contracts, eth...           NaN
# 13  [smart-contracts, three-arrows-capital-portfol...  7.157487e+08
# 14  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
# 15  [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 16  [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 17  [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 18  [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 19  [marketplace, centralized-exchange, payments, ...           NaN
# 20  [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 21  [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 22  [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 23  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 24  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 25  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 26  [decentralized-exchange-dex-token, defi, deriv...  1.000000e+09
# 27  [platform, defi, oracles, smart-contracts, eth...           NaN
# 28  [smart-contracts, three-arrows-capital-portfol...  7.157487e+08
# 29  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.987106e+07  1.987106e+07  ...                         62.8599
# 1         1.207252e+08  1.207252e+08  ...                          9.3585
# 2         1.529134e+11  1.560043e+11  ...                          4.4508
# 3         5.868601e+10  9.998611e+10  ...                          3.9310
# 4         1.408879e+08  1.408879e+08  ...                          2.8161
# 5         5.205269e+08  6.018278e+08  ...                          2.6315
# 6         6.137992e+10  6.137992e+10  ...                          1.7856
# 7         1.494506e+11  1.494506e+11  ...                          0.9685
# 8         3.533451e+10  4.499450e+10  ...                          0.7795
# 9         9.487200e+10  9.487205e+10  ...                          0.7598
# 10        3.338327e+09  1.000000e+10  ...                          0.3572
# 11        3.339282e+08  9.999939e+08  ...                          0.3401
# 12        6.571000e+08  1.000000e+09  ...                          0.3047
# 13        4.211581e+08  4.561608e+08  ...                          0.2877
# 14        3.111580e+10  5.000179e+10  ...                          0.2607
# 15        1.987106e+07  1.987106e+07  ...                         62.8761
# 16        1.207252e+08  1.207252e+08  ...                          9.3609
# 17        1.529134e+11  1.560043e+11  ...                          4.4507
# 18        5.868601e+10  9.998611e+10  ...                          3.9308
# 19        1.408879e+08  1.408879e+08  ...                          2.8161
# 20        5.205269e+08  6.018278e+08  ...                          2.6312
# 21        6.137992e+10  6.137992e+10  ...                          1.7850
# 22        1.494506e+11  1.494506e+11  ...                          0.9684
# 23        3.533451e+10  4.499450e+10  ...                          0.7794
# 24        9.487200e+10  9.487205e+10  ...                          0.7598
# 25        3.338327e+09  1.000000e+10  ...                          0.3573
# 26        3.339282e+08  9.999939e+08  ...                          0.3398
# 27        6.571000e+08  1.000000e+09  ...                          0.3046
# 28        4.211581e+08  4.561608e+08  ...                          0.2876
# 29        3.111580e+10  5.000179e+10  ...                          0.2607
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         2.283045e+12           None
# 1                         3.216229e+11           None
# 2                         1.560532e+11           None
# 3                         2.302049e+11           None
# 4                         9.678005e+10           None
# 5                         1.045620e+11           None
# 6                         6.136664e+10           None
# 7                         3.328393e+10           None
# 8                         3.411577e+10           None
# 9                         2.611240e+10           None
# 10                        3.678806e+10           None
# 11                        3.500209e+10           None
# 12                        1.593369e+10           None
# 13                        1.680115e+10           None
# 14                        1.440518e+10           None
# 15                        2.283635e+12           None
# 16                        3.217068e+11           None
# 17                        1.560501e+11           None
# 18                        2.301883e+11           None
# 19                        9.678156e+10           None
# 20                        1.045501e+11           None
# 21                        6.134532e+10           None
# 22                        3.328127e+10           None
# 23                        3.411253e+10           None
# 24                        2.611215e+10           None
# 25                        3.680384e+10           None
# 26                        3.497522e+10           None
# 27                        1.593108e+10           None
# 28                        1.679992e+10           None
# 29                        1.440473e+10           None
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 1   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 2   2025-05-28T13:22:00.000Z       1027.0      Ethereum             ETH
# 3   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 4   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 5   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 6   2025-05-28T13:23:00.000Z       1027.0      Ethereum             ETH
# 7   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 8   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 9   2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 10  2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 11  2025-05-28T13:23:00.000Z      32196.0   Hyperliquid            HYPE
# 12  2025-05-28T13:23:00.000Z       1027.0      Ethereum             ETH
# 13  2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 14  2025-05-28T13:23:00.000Z          NaN           NaN             NaN
# 15  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 16  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 17  2025-05-28T13:23:00.000Z       1027.0      Ethereum             ETH
# 18  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 19  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 20  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 21  2025-05-28T13:24:00.000Z       1027.0      Ethereum             ETH
# 22  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 23  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 24  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 25  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 26  2025-05-28T13:24:00.000Z      32196.0   Hyperliquid            HYPE
# 27  2025-05-28T13:24:00.000Z       1027.0      Ethereum             ETH
# 28  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
# 29  2025-05-28T13:24:00.000Z          NaN           NaN             NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5             NaN                                         NaN
# 6        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 12       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13            NaN                                         NaN
# 14            NaN                                         NaN
# 15            NaN                                         NaN
# 16            NaN                                         NaN
# 17       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18            NaN                                         NaN
# 19            NaN                                         NaN
# 20            NaN                                         NaN
# 21       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22            NaN                                         NaN
# 23            NaN                                         NaN
# 24            NaN                                         NaN
# 25            NaN                                         NaN
# 26    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 27       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 28            NaN                                         NaN
# 29            NaN                                         NaN
#
#                     Timestamp
# 0  2025-05-28 19:09:14.422573
# 1  2025-05-28 19:09:14.422573
# 2  2025-05-28 19:09:14.422573
# 3  2025-05-28 19:09:14.422573
# 4  2025-05-28 19:09:14.422573
# 5  2025-05-28 19:09:14.422573
# 6  2025-05-28 19:09:14.422573
# 7  2025-05-28 19:09:14.422573
# 8  2025-05-28 19:09:14.422573
# 9  2025-05-28 19:09:14.422573
# 10 2025-05-28 19:09:14.422573
# 11 2025-05-28 19:09:14.422573
# 12 2025-05-28 19:09:14.422573
# 13 2025-05-28 19:09:14.422573
# 14 2025-05-28 19:09:14.422573
# 15 2025-05-28 19:10:20.711120
# 16 2025-05-28 19:10:20.711120
# 17 2025-05-28 19:10:20.711120
# 18 2025-05-28 19:10:20.711120
# 19 2025-05-28 19:10:20.711120
# 20 2025-05-28 19:10:20.711120
# 21 2025-05-28 19:10:20.711120
# 22 2025-05-28 19:10:20.711120
# 23 2025-05-28 19:10:20.711120
# 24 2025-05-28 19:10:20.711120
# 25 2025-05-28 19:10:20.711120
# 26 2025-05-28 19:10:20.711120
# 27 2025-05-28 19:10:20.711120
# 28 2025-05-28 19:10:20.711120
# 29 2025-05-28 19:10:20.711120
#
# [30 rows x 37 columns]

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol         slug  num_market_pairs  \
# 0       1      Bitcoin    BTC      bitcoin             12198
# 1    1027     Ethereum    ETH     ethereum             10316
# 2     825  Tether USDt   USDT       tether            129964
# 3      52          XRP    XRP          xrp              1617
# 4    1839          BNB    BNB          bnb              2553
# 5    5426       Solana    SOL       solana               927
# 6    3408         USDC   USDC     usd-coin             28281
# 7      74     Dogecoin   DOGE     dogecoin              1229
# 8    2010      Cardano    ADA      cardano              1524
# 9    1958         TRON    TRX         tron              1181
# 10  20947          Sui    SUI          sui               667
# 11  32196  Hyperliquid   HYPE  hyperliquid                87
# 12   1975    Chainlink   LINK    chainlink              2016
# 13   5805    Avalanche   AVAX    avalanche               917
# 14    512      Stellar    XLM      stellar               709
# 15      1      Bitcoin    BTC      bitcoin             12198
# 16   1027     Ethereum    ETH     ethereum             10316
# 17    825  Tether USDt   USDT       tether            129964
# 18     52          XRP    XRP          xrp              1617
# 19   1839          BNB    BNB          bnb              2553
# 20   5426       Solana    SOL       solana               927
# 21   3408         USDC   USDC     usd-coin             28281
# 22     74     Dogecoin   DOGE     dogecoin              1229
# 23   2010      Cardano    ADA      cardano              1524
# 24   1958         TRON    TRX         tron              1181
# 25  20947          Sui    SUI          sui               667
# 26  32196  Hyperliquid   HYPE  hyperliquid                87
# 27   1975    Chainlink   LINK    chainlink              2016
# 28   5805    Avalanche   AVAX    avalanche               917
# 29    512      Stellar    XLM      stellar               709
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-10-01T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2022-07-12T08:03:11.000Z
# 11  2024-07-15T10:14:50.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2020-07-13T00:00:00.000Z
# 14  2014-08-05T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2013-08-04T00:00:00.000Z
# 19  2017-07-25T00:00:00.000Z
# 20  2020-04-10T00:00:00.000Z
# 21  2018-10-08T00:00:00.000Z
# 22  2013-12-15T00:00:00.000Z
# 23  2017-10-01T00:00:00.000Z
# 24  2017-09-13T00:00:00.000Z
# 25  2022-07-12T08:03:11.000Z
# 26  2024-07-15T10:14:50.000Z
# 27  2017-09-20T00:00:00.000Z
# 28  2020-07-13T00:00:00.000Z
# 29  2014-08-05T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...                NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp... 100000000000.00000
# 4   [marketplace, centralized-exchange, payments, ...                NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 9   [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 10  [binance-launchpool, coinbase-ventures-portfol...  10000000000.00000
# 11  [decentralized-exchange-dex-token, defi, deriv...   1000000000.00000
# 12  [platform, defi, oracles, smart-contracts, eth...                NaN
# 13  [smart-contracts, three-arrows-capital-portfol...    715748719.00000
# 14  [medium-of-exchange, enterprise-solutions, dec...  50001806812.00000
# 15  [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 16  [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 17  [stablecoin, asset-backed-stablecoin, usd-stab...                NaN
# 18  [medium-of-exchange, enterprise-solutions, xrp... 100000000000.00000
# 19  [marketplace, centralized-exchange, payments, ...                NaN
# 20  [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 21  [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 22  [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 23  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 24  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 25  [binance-launchpool, coinbase-ventures-portfol...  10000000000.00000
# 26  [decentralized-exchange-dex-token, defi, deriv...   1000000000.00000
# 27  [platform, defi, oracles, smart-contracts, eth...                NaN
# 28  [smart-contracts, three-arrows-capital-portfol...    715748719.00000
# 29  [medium-of-exchange, enterprise-solutions, dec...  50001806812.00000
#
#     circulating_supply       total_supply  ...  \
# 0       19871056.00000     19871056.00000  ...
# 1      120725247.07261    120725247.07261  ...
# 2   152913418919.93286 156004270711.01822  ...
# 3    58686007292.00000  99986107098.00000  ...
# 4      140887900.00000    140887900.00000  ...
# 5      520526933.41375    601827800.13479  ...
# 6    61379922073.50623  61379922073.50623  ...
# 7   149450576383.70523 149450566383.70523  ...
# 8    35334514487.46726  44994495302.31451  ...
# 9    94872002301.25616  94872047141.44081  ...
# 10    3338327017.91167  10000000000.00000  ...
# 11     333928180.00000    999993930.00000  ...
# 12     657099970.45279   1000000000.00000  ...
# 13     421158067.50439    456160767.50439  ...
# 14   31115799981.19448  50001786892.81785  ...
# 15      19871056.00000     19871056.00000  ...
# 16     120725247.07261    120725247.07261  ...
# 17  152913418919.93286 156004270711.01822  ...
# 18   58686007292.00000  99986107098.00000  ...
# 19     140887900.00000    140887900.00000  ...
# 20     520526933.41375    601827800.13479  ...
# 21   61379922073.50623  61379922073.50623  ...
# 22  149450576383.70523 149450566383.70523  ...
# 23   35334514487.46726  44994495302.31451  ...
# 24   94872002301.25616  94872047141.44081  ...
# 25    3338327017.91167  10000000000.00000  ...
# 26     333928180.00000    999993930.00000  ...
# 27     657099970.45279   1000000000.00000  ...
# 28     421158067.50439    456160767.50439  ...
# 29   31115799981.19448  50001786892.81785  ...
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         62.85990                 2283044628335.27002
# 1                          9.35850                  321622906477.00000
# 2                          4.45080                  156053226943.37000
# 3                          3.93100                  230204874442.10999
# 4                          2.81610                   96780049100.42000
# 5                          2.63150                  104562042611.03999
# 6                          1.78560                   61366641955.24000
# 7                          0.96850                   33283932498.90000
# 8                          0.77950                   34115774270.99000
# 9                          0.75980                   26112402432.76000
# 10                         0.35720                   36788056126.01000
# 11                         0.34010                   35002092758.68000
# 12                         0.30470                   15933687882.88000
# 13                         0.28770                   16801151653.49000
# 14                         0.26070                   14405184534.85000
# 15                        62.87610                 2283634509508.29980
# 16                         9.36090                  321706800680.75000
# 17                         4.45070                  156050090736.25000
# 18                         3.93080                  230188317439.31000
# 19                         2.81610                   96781557672.03999
# 20                         2.63120                  104550138347.13000
# 21                         1.78500                   61345320034.73000
# 22                         0.96840                   33281270599.73000
# 23                         0.77940                   34112533174.78000
# 24                         0.75980                   26112147141.11000
# 25                         0.35730                   36803837190.73000
# 26                         0.33980                   34975216105.98000
# 27                         0.30460                   15931079437.43000
# 28                         0.28760                   16799921359.34000
# 29                         0.26070                   14404732213.44000
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 1            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 2            None  2025-05-28T13:22:00.000Z   1027.00000      Ethereum
# 3            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 4            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 5            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 6            None  2025-05-28T13:23:00.000Z   1027.00000      Ethereum
# 7            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 8            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 9            None  2025-05-28T13:23:00.000Z          NaN           NaN
# 10           None  2025-05-28T13:23:00.000Z          NaN           NaN
# 11           None  2025-05-28T13:23:00.000Z  32196.00000   Hyperliquid
# 12           None  2025-05-28T13:23:00.000Z   1027.00000      Ethereum
# 13           None  2025-05-28T13:23:00.000Z          NaN           NaN
# 14           None  2025-05-28T13:23:00.000Z          NaN           NaN
# 15           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 16           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 17           None  2025-05-28T13:23:00.000Z   1027.00000      Ethereum
# 18           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 19           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 20           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 21           None  2025-05-28T13:24:00.000Z   1027.00000      Ethereum
# 22           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 23           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 24           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 25           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 26           None  2025-05-28T13:24:00.000Z  32196.00000   Hyperliquid
# 27           None  2025-05-28T13:24:00.000Z   1027.00000      Ethereum
# 28           None  2025-05-28T13:24:00.000Z          NaN           NaN
# 29           None  2025-05-28T13:24:00.000Z          NaN           NaN
#
#    platform.symbol  platform.slug                      platform.token_address  \
# 0              NaN            NaN                                         NaN
# 1              NaN            NaN                                         NaN
# 2              ETH       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN            NaN                                         NaN
# 4              NaN            NaN                                         NaN
# 5              NaN            NaN                                         NaN
# 6              ETH       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN            NaN                                         NaN
# 8              NaN            NaN                                         NaN
# 9              NaN            NaN                                         NaN
# 10             NaN            NaN                                         NaN
# 11            HYPE    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 12             ETH       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13             NaN            NaN                                         NaN
# 14             NaN            NaN                                         NaN
# 15             NaN            NaN                                         NaN
# 16             NaN            NaN                                         NaN
# 17             ETH       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18             NaN            NaN                                         NaN
# 19             NaN            NaN                                         NaN
# 20             NaN            NaN                                         NaN
# 21             ETH       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22             NaN            NaN                                         NaN
# 23             NaN            NaN                                         NaN
# 24             NaN            NaN                                         NaN
# 25             NaN            NaN                                         NaN
# 26            HYPE    hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 27             ETH       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 28             NaN            NaN                                         NaN
# 29             NaN            NaN                                         NaN
#
#                     Timestamp
# 0  2025-05-28 19:09:14.422573
# 1  2025-05-28 19:09:14.422573
# 2  2025-05-28 19:09:14.422573
# 3  2025-05-28 19:09:14.422573
# 4  2025-05-28 19:09:14.422573
# 5  2025-05-28 19:09:14.422573
# 6  2025-05-28 19:09:14.422573
# 7  2025-05-28 19:09:14.422573
# 8  2025-05-28 19:09:14.422573
# 9  2025-05-28 19:09:14.422573
# 10 2025-05-28 19:09:14.422573
# 11 2025-05-28 19:09:14.422573
# 12 2025-05-28 19:09:14.422573
# 13 2025-05-28 19:09:14.422573
# 14 2025-05-28 19:09:14.422573
# 15 2025-05-28 19:10:20.711120
# 16 2025-05-28 19:10:20.711120
# 17 2025-05-28 19:10:20.711120
# 18 2025-05-28 19:10:20.711120
# 19 2025-05-28 19:10:20.711120
# 20 2025-05-28 19:10:20.711120
# 21 2025-05-28 19:10:20.711120
# 22 2025-05-28 19:10:20.711120
# 23 2025-05-28 19:10:20.711120
# 24 2025-05-28 19:10:20.711120
# 25 2025-05-28 19:10:20.711120
# 26 2025-05-28 19:10:20.711120
# 27 2025-05-28 19:10:20.711120
# 28 2025-05-28 19:10:20.711120
# 29 2025-05-28 19:10:20.711120
#
# [30 rows x 37 columns]

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.25870                      -1.58865
# Ethereum                        -0.41591                      -0.23416
# Tether USDt                      0.03620                      -0.00967
# XRP                             -0.41665                      -1.99130
# BNB                             -0.24093                       0.04008
# Solana                          -0.59168                      -2.86770
# USDC                            -0.00040                      -0.03191
# Dogecoin                        -0.47888                      -3.93240
# Cardano                         -0.17767                      -2.12059
# TRON                            -0.19803                      -0.16701
# Sui                             -0.28886                       0.77844
# Hyperliquid                     -1.78642                      -9.39698
# Chainlink                       -0.45549                      -0.91396
# Avalanche                       -0.49583                      -1.56287
# Stellar                         -0.31146                      -1.42918
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          2.13927                      14.16417
# Ethereum                         5.33081                      47.55791
# Tether USDt                      0.00057                      -0.01186
# XRP                             -2.04681                      -0.77480
# BNB                              5.22634                      13.18355
# Solana                           2.99536                      15.51175
# USDC                            -0.02288                      -0.03681
# Dogecoin                        -1.47600                      23.34264
# Cardano                          1.04083                       5.97775
# TRON                             1.65525                      11.89016
# Sui                             -5.97584                      -1.73734
# Hyperliquid                     32.57922                      92.20441
# Chainlink                        1.62177                       6.71191
# Avalanche                        3.94813                       6.64853
# Stellar                         -0.54981                       0.13467
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          31.54315                      26.09019
# Ethereum                         43.25419                      13.49355
# Tether USDt                       0.05980                       0.10886
# XRP                               8.35374                       3.30756
# BNB                              13.36526                      12.54039
# Solana                           37.69654                      24.19352
# USDC                             -0.03771                      -0.04266
# Dogecoin                         29.40493                       6.43251
# Cardano                          12.31957                      12.42181
# TRON                             17.66056                      20.06163
# Sui                              58.67655                      26.46880
# Hyperliquid                     171.62475                      70.57092
# Chainlink                        15.41105                       1.71676
# Avalanche                        16.14580                       1.46695
# Stellar                           6.92774                      -0.58797

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin  quote.USD.percent_change_1h    -0.25870
#          quote.USD.percent_change_24h   -1.58865
#          quote.USD.percent_change_7d     2.13927
#          quote.USD.percent_change_30d   14.16417
#          quote.USD.percent_change_60d   31.54315
#                                           ...
# Stellar  quote.USD.percent_change_24h   -1.42918
#          quote.USD.percent_change_7d    -0.54981
#          quote.USD.percent_change_30d    0.13467
#          quote.USD.percent_change_60d    6.92774
#          quote.USD.percent_change_90d   -0.58797
# Length: 90, dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                        values
# name
# Bitcoin quote.USD.percent_change_1h  -0.25870
#         quote.USD.percent_change_24h -1.58865
#         quote.USD.percent_change_7d   2.13927
#         quote.USD.percent_change_30d 14.16417
#         quote.USD.percent_change_60d 31.54315
# ...                                       ...
# Stellar quote.USD.percent_change_24h -1.42918
#         quote.USD.percent_change_7d  -0.54981
#         quote.USD.percent_change_30d  0.13467
#         quote.USD.percent_change_60d  6.92774
#         quote.USD.percent_change_90d -0.58797
#
# [90 rows x 1 columns]

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe.

index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#        name                       level_1   values
# 0   Bitcoin   quote.USD.percent_change_1h -0.25870
# 1   Bitcoin  quote.USD.percent_change_24h -1.58865
# 2   Bitcoin   quote.USD.percent_change_7d  2.13927
# 3   Bitcoin  quote.USD.percent_change_30d 14.16417
# 4   Bitcoin  quote.USD.percent_change_60d 31.54315
# ..      ...                           ...      ...
# 85  Stellar  quote.USD.percent_change_24h -1.42918
# 86  Stellar   quote.USD.percent_change_7d -0.54981
# 87  Stellar  quote.USD.percent_change_30d  0.13467
# 88  Stellar  quote.USD.percent_change_60d  6.92774
# 89  Stellar  quote.USD.percent_change_90d -0.58797
#
# [90 rows x 3 columns]

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#        name                percent_change   values
# 0   Bitcoin   quote.USD.percent_change_1h -0.25870
# 1   Bitcoin  quote.USD.percent_change_24h -1.58865
# 2   Bitcoin   quote.USD.percent_change_7d  2.13927
# 3   Bitcoin  quote.USD.percent_change_30d 14.16417
# 4   Bitcoin  quote.USD.percent_change_60d 31.54315
# ..      ...                           ...      ...
# 85  Stellar  quote.USD.percent_change_24h -1.42918
# 86  Stellar   quote.USD.percent_change_7d -0.54981
# 87  Stellar  quote.USD.percent_change_30d  0.13467
# 88  Stellar  quote.USD.percent_change_60d  6.92774
# 89  Stellar  quote.USD.percent_change_90d -0.58797
#
# [90 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#        name percent_change   values
# 0   Bitcoin             1h -0.25870
# 1   Bitcoin            24h -1.58865
# 2   Bitcoin             7d  2.13927
# 3   Bitcoin            30d 14.16417
# 4   Bitcoin            60d 31.54315
# ..      ...            ...      ...
# 85  Stellar            24h -1.42918
# 86  Stellar             7d -0.54981
# 87  Stellar            30d  0.13467
# 88  Stellar            60d  6.92774
# 89  Stellar            90d -0.58797
#
# [90 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Now to do something much simpler
# To create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','Timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#        name  quote.USD.price                  Timestamp
# 0   Bitcoin     108716.41087 2025-05-28 19:09:14.422573
# 15  Bitcoin     108744.50045 2025-05-28 19:10:20.711120

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='Timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='Timestamp', ylabel='quote.USD.price'>
